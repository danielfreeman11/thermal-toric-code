# %%
# %matplotlib inline
import matplotlib
import numpy
import os
import mplrc
#os.chdir("./PaperDataFiles/EnergyDataset") #comment out to read from testdatafile
os.chdir("./PaperDataFiles/BigDataset")

import math
import numpy as np
import matplotlib.pyplot as plt
import argparse
import numpy

from scipy.optimize import curve_fit

#from MCbatch import *
#import estimators as est


import pylab as pl

pl.rcParams.update(mplrc.aps['params'])

# %%
colors = ["#568493", "#C24D3B", "#C157C8", "#619D48", "#B0527A", "#A47B33", "#7674BF","#ADFF2F",
            "#568493", "#C24D3B", "#C157C8", "#619D48", "#B0527A", "#A47B33", "#7674BF",
            "#568493", "#C24D3B", "#C157C8", "#619D48", "#B0527A", "#A47B33", "#7674BF"]
#matplotlib.rcParams.update(mplrc.aps['params'])
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.plot()
# Out:
# []

# %%
#!/usr/bin/python
# pubPlot.py
# Chris Herdman
# 01.13.2014
# 
# Sample of publication quality matplotlib plots
# Requires text files with data in columns. The
# first row begins with an "#" and has the column
# labels. The first column is the x-data followed
# by y-data alternating with errorbars, if used. 








plt.rc('text', usetex=True)
plt.rc('font', family='serif')
numpy.set_printoptions(formatter={'float': lambda x: format(x, '6.3E')})

# %%
mydata = []
myfilenums = []
#
#with open("TestDataFile.txt") as f:
#    mydata = f.readlines()
for f in os.listdir('.'):
    with open(f) as ff:
        lines = ff.readlines()
        if lines!=[]:
            #print lines[-1]
            mydata.append(lines[-1])
            myfilenums.append(f.split(".")[-1])

# %%
print len(mydata)
# Out:
# 11328

# %%
datadict = {}
for m in mydata:
    
    splitlist = m.split("\t")
    if len(splitlist)>2:
        key = splitlist[0:4]
        val = splitlist[5]
        valerr = splitlist[6]
        #print key,val
        if tuple(key) in datadict:
            datadict[tuple(key)][0].append(float(val))
            datadict[tuple(key)][1].append(float(valerr))
        else:
            datadict[tuple(key)] = [[float(val)],[float(valerr)]]

# %%
datadict2 = {}
for m in mydata:
    
    splitlist = m.split("\t")
    if len(splitlist)>2:
        key = splitlist[0:4]
        val = splitlist[5]
        valerr = splitlist[6]
        #print key,val
        if tuple(key) in datadict:
            datadict2[tuple(key)][0].append(float(val))
            datadict2[tuple(key)][1].append(float(valerr))
        else:
            datadict2[tuple(key)] = [[float(val)],[float(valerr)]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ee02cce508eb> in <module>()
#      10         #print key,val
#      11         if tuple(key) in datadict:
# ---> 12             datadict2[tuple(key)][0].append(float(val))
#      13             datadict2[tuple(key)][1].append(float(valerr))
#      14         else:
#
# KeyError: ('0.39 ', '7 ', '2 ', '14 ')

# %%
for d in datadict:
    print "\t".join(d),"\t",str(numpy.average(datadict[d][0])),"\t",str(numpy.sqrt(sum([d*d/numpy.sqrt(10.) for d in datadict[d][1]]))/10.)
    #datadict[d] = (numpy.average(datadict[d][0]),numpy.sqrt(sum([d*d/numpy.sqrt(10.) for d in datadict[d][1]]))/10.)
# Out:
# 0.18 	7 	4 	28  	1256.88615816 	223.995895717
# 0.37 	10 	8 	80  	21.6941182304 	1.75917962436
# 0.28 	7 	3 	21  	48.7925272889 	6.72394952908
# 0.1 	10 	4 	40  	536551.447941 	97150.5553692
# 0.2 	10 	12 	120  	302.607166871 	32.0042864918
# 0.15 	15 	2 	30  	1901.69140449 	294.834684919
# 0.33 	10 	8 	80  	27.5351977943 	2.60415451977
# 0.36 	7 	4 	28  	16.8826161404 	1.75272491581
# 0.08 	7 	12 	84  	2771977048.32 	501115735.747
# 0.13 	7 	2 	14  	8051.46689969 	1238.22171628
# 0.19 	7 	6 	42  	736.766871869 	125.062941345
# 0.27 	15 	16 	240  	78.0572435877 	6.24706090961
# 0.12 	15 	8 	120  	48825.6498353 	6910.34724652
# 0.07 	10 	2 	20  	9466812.98009 	1471487.08854
# 0.26 	10 	8 	80  	69.4923032543 	6.46193390142
# 0.11 	15 	32 	480  	503221.822641 	86429.595078
# 0.24 	15 	12 	180  	122.957520724 	8.96284159729
# 0.07 	15 	12 	180  	10036580968.1 	1765365066.77
# 0.15 	15 	24 	360  	2605.48962172 	318.572543962
# 0.2 	15 	4 	60  	257.674878781 	30.9545220539
# ...

# %%
saveFig = False

f, ax = plt.subplots()

parseddata = []
'''lambdas = []
with open("outputwitherror_fixed.txt") as f:
    data = f.readlines()
    for line in data:
        d = [float(l) for l in line.split("\t")]
        if len(d)>2:
            if d[1] in lambdas:
                parseddata[lambdas.index(d[1])].append(d)
            else:
                lambdas.append(d[1])
                parseddata.append([])
                parseddata[lambdas.index(d[1])].append(d)'''

#parseddata = [sorted(d, key=lambda x: x[2]) for d in parseddata]
#parseddata = sorted(parseddata, key=lambda x: x[0][1])


datasets = []

for t in [.09,.12,.15,.18,.21,.24]:
    
    xdat = []
    ydat = []
    yerror = []

    for d in datadict:
        dd = [float(ddd) for ddd in d]
        if dd[0] == t and dd[1] == 7:
            print t,dd[2],"\t",numpy.average(datadict[d][0])
            xdat.append(7.*float(d[2]))
            ydat.append(numpy.average(datadict[d][0])/numpy.exp(1./t))
            yerror.append(numpy.sqrt(sum([d*d/numpy.sqrt(10.) for d in datadict[d][1]]))/(10.*numpy.exp(1./t)))

    datasets.append([t,xdat,ydat,yerror])
# Out:
# 0.09 8.0 	144091390.211
# 0.09 6.0 	31331899.4612
# 0.09 24.0 	544406303.272
# 0.09 3.0 	158513.5613
# 0.09 12.0 	152678594.499
# 0.09 2.0 	279963.946364
# 0.09 16.0 	190504795.673
# 0.09 4.0 	3837055.63029
# 0.09 32.0 	2011466084.68
# 0.12 16.0 	556450.882557
# 0.12 12.0 	431720.192894
# 0.12 32.0 	1494299.2293
# 0.12 2.0 	15491.5450313
# 0.12 8.0 	564465.169977
# 0.12 24.0 	935679.504329
# 0.12 6.0 	371551.480194
# 0.12 4.0 	117145.499029
# 0.12 3.0 	11351.770098
# 0.15 12.0 	10910.3601934
# 0.15 8.0 	12027.4473728
# 0.15 16.0 	11028.4814526
# 0.15 24.0 	9314.90333547
# 0.15 3.0 	1939.67615975
# 0.15 6.0 	14751.0407561
# 0.15 2.0 	2607.35424837
# 0.15 4.0 	11053.7150042
# 0.15 32.0 	10010.6516573
# 0.18 4.0 	1256.88615816
# 0.18 12.0 	824.754886397
# 0.18 8.0 	1091.05298717
# 0.18 16.0 	738.848755407
# 0.18 2.0 	565.475452851
# 0.18 24.0 	658.593487428
# 0.18 32.0 	595.813494979
# 0.18 6.0 	1375.62121188
# 0.18 3.0 	693.754371426
# 0.21 8.0 	217.548487727
# ...

# %%
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-small')


plt.subplot(111,  yscale="log") 
plt.xlim(0,7*35)
plt.ylim(1*10**0,10*10**6)
plt.xlabel(r'$L$')
plt.ylabel(r'$(\Gamma/\Gamma_0)^{-1}$')
#matplotlib.pyplot.yscale('log')
#matplotlib.pyplot.xscale('log')
#labellist=[96/d[1]3,4,6,8,12,16]


for i,d in enumerate(datasets):
    xdat = d[1]
    
    
    temp = d[0]
    ydat = d[2]
    yerror = d[3]
    plt.errorbar(xdat,ydat,label=r'$T$=' + str(temp), \
                linestyle=' ',markersize=5,marker='.',linewidth=0,elinewidth=.5,color=colors[i],\
               yerr = yerror)
#print [dd[4]/dd[3] for dd in d]
#plt.loglog([dd[2] for dd in d],[dd[3]+dd[4] for dd in d], \
#               linestyle='-',markersize=5,marker='_',linewidth=0,color='black')
#plt.loglog([dd[2] for dd in d],[dd[3]-dd[4] for dd in d], \
#                linestyle='-',markersize=5,marker='_',linewidth=0,color='black')

#print handlelist
#plt.legend(loc=2,ncol=2,numpoints=1,bbox_to_anchor=(1.05, 1), borderaxespad=0.)
leg = plt.legend(loc=2,ncol=2,numpoints=1, borderaxespad=.5,prop = fontP, frameon=False)

for legobj in leg.legendHandles:
    legobj.set_linewidth(.5)


plt.savefig('LifetimeVsSystemsize'+'.pdf',dpi=600,bbox_inches='tight')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-small')


plt.subplot(111,  yscale="log") 
plt.xlim(0,7*35)
plt.ylim(1*10**-3,10*10**0)
#plt.xlabel(r'$\lambda = \rm{\#\ of\ patches}$')
plt.xlabel(r'$L$')
plt.ylabel(r'$(\Gamma/\Gamma_0^2)^{-1}$')
#matplotlib.pyplot.yscale('log')
#matplotlib.pyplot.xscale('log')
#labellist=[96/d[1]3,4,6,8,12,16]


for i,d in enumerate(datasets):
    xdat = d[1]
    
    
    temp = d[0]
    ydat = [dd/(numpy.exp(1./temp)) for dd in  d[2]]
    yerror = [dd/(numpy.exp(1./temp)) for dd in d[3]]
    plt.errorbar(xdat,ydat,label=r'$T$=' + str(temp), \
                linestyle='dots',markersize=5,marker='.',linewidth=0,elinewidth=.5,color=colors[i],\
               yerr = yerror)
#print [dd[4]/dd[3] for dd in d]
#plt.loglog([dd[2] for dd in d],[dd[3]+dd[4] for dd in d], \
#               linestyle='-',markersize=5,marker='_',linewidth=0,color='black')
#plt.loglog([dd[2] for dd in d],[dd[3]-dd[4] for dd in d], \
#                linestyle='-',markersize=5,marker='_',linewidth=0,color='black')

#print handlelist
#plt.legend(loc=2,ncol=2,numpoints=1,bbox_to_anchor=(1.05, 1), borderaxespad=0.)
leg = plt.legend(loc=2,ncol=2,numpoints=1, borderaxespad=.5,prop = fontP, frameon=False)

for legobj in leg.legendHandles:
    legobj.set_linewidth(.5)


plt.savefig('LifetimeVsSystemsizeReduced'+'.pdf',dpi=600,bbox_inches='tight')

# %%
saveFig = False

f, ax = plt.subplots()

parseddata = []
'''lambdas = []
with open("outputwitherror_fixed.txt") as f:
    data = f.readlines()
    for line in data:
        d = [float(l) for l in line.split("\t")]
        if len(d)>2:
            if d[1] in lambdas:
                parseddata[lambdas.index(d[1])].append(d)
            else:
                lambdas.append(d[1])
                parseddata.append([])
                parseddata[lambdas.index(d[1])].append(d)'''

#parseddata = [sorted(d, key=lambda x: x[2]) for d in parseddata]
#parseddata = sorted(parseddata, key=lambda x: x[0][1])


datasets = []

for x in [2,4,6,8,12,16,24,32]:
    
    xdat = []
    ydat = []
    yerror = []

    for d in datadict:
        dd = [float(ddd) for ddd in d]
        if dd[2] == x and dd[1] == 7:
            t = dd[0]
            print t,"\t",x,"\t",dd[2],"\t",numpy.average(datadict[d][0])
            xdat.append(d[0])
            ydat.append(numpy.average(datadict[d][0])/numpy.exp(1./t))
            yerror.append(numpy.sqrt(sum([d*d/numpy.sqrt(10.) for d in datadict[d][1]]))/(10.*numpy.exp(1./t)))

    datasets.append([x,xdat,ydat,yerror])
# Out:
# 0.13 	2 	2.0 	8051.46689969
# 0.07 	2 	2.0 	11449952.304
# 0.24 	2 	2.0 	97.1374829797
# 0.29 	2 	2.0 	41.4489231411
# 0.4 	2 	2.0 	12.2618354806
# 0.12 	2 	2.0 	15491.5450313
# 0.37 	2 	2.0 	15.0264907885
# 0.39 	2 	2.0 	12.2377163772
# 0.11 	2 	2.0 	44228.2098615
# 0.34 	2 	2.0 	17.7033709793
# 0.18 	2 	2.0 	565.475452851
# 0.08 	2 	2.0 	1306173.61696
# 0.3 	2 	2.0 	34.3825875291
# 0.27 	2 	2.0 	55.2804633255
# 0.28 	2 	2.0 	40.928486646
# 0.16 	2 	2.0 	1732.06207263
# 0.09 	2 	2.0 	279963.946364
# 0.33 	2 	2.0 	25.0211590405
# 0.31 	2 	2.0 	25.1784747701
# 0.25 	2 	2.0 	70.2321793377
# 0.1 	2 	2.0 	91742.6069785
# 0.22 	2 	2.0 	160.803419967
# 0.35 	2 	2.0 	17.08538764
# 0.15 	2 	2.0 	2607.35424837
# 0.36 	2 	2.0 	13.5456654483
# 0.38 	2 	2.0 	14.0806903998
# 0.23 	2 	2.0 	125.022516202
# 0.21 	2 	2.0 	213.143591245
# 0.2 	2 	2.0 	309.817938239
# 0.14 	2 	2.0 	4554.42220112
# 0.17 	2 	2.0 	1032.00438772
# 0.32 	2 	2.0 	26.2490520669
# 0.19 	2 	2.0 	421.085428033
# ...

# %%
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-small')


plt.subplot(111,  yscale="log") 
plt.xlim(0,.4)
plt.ylim(1*10**0,10*10**5)
plt.xlabel(r'$\rm{Temperature}$')
plt.ylabel(r'$(\Gamma/\Gamma_0)^{-1}$')
#matplotlib.pyplot.yscale('log')
#matplotlib.pyplot.xscale('log')
#labellist=[96/d[1]3,4,6,8,12,16]


for i,d in enumerate(datasets):
    if d[0] in [2,4,8,32]:
        xdat = d[1]
        ydat = d[2]
        yerror = d[3]
        
        thisdata = []
        for j,t in enumerate(xdat):
            thisdata.append([xdat[j],ydat[j],yerror[j]])
            
        thisdata = sorted(thisdata, key = lambda x: x[0])
        
        xdat = [t[0] for t in thisdata]
        ydat = [t[1] for t in thisdata]
        yerror = [t[2] for t in thisdata]
        
        
        size = d[0]
        plt.errorbar(xdat,ydat,label=r'$L$=' + str(7*size), \
                    linestyle='-',markersize=5,marker='.',linewidth=.5,elinewidth=.5,color=colors[i],\
                   yerr = yerror)
    
    #print xdat
#print [dd[4]/dd[3] for dd in d]
#plt.loglog([dd[2] for dd in d],[dd[3]+dd[4] for dd in d], \
#               linestyle='-',markersize=5,marker='_',linewidth=0,color='black')
#plt.loglog([dd[2] for dd in d],[dd[3]-dd[4] for dd in d], \
#                linestyle='-',markersize=5,marker='_',linewidth=0,color='black')

#print handlelist
#plt.legend(loc=2,ncol=2,numpoints=1,bbox_to_anchor=(1.05, 1), borderaxespad=0.)
leg = plt.legend(loc=1,ncol=2,numpoints=1, borderaxespad=.5,prop = fontP, frameon=False)

for legobj in leg.legendHandles:
    legobj.set_linewidth(.5)


plt.savefig('LifetimeVsTemperature'+'.pdf',dpi=600,bbox_inches='tight')

# %%
saveFig = False

f, ax = plt.subplots()

parseddata = []
'''lambdas = []
with open("outputwitherror_fixed.txt") as f:
    data = f.readlines()
    for line in data:
        d = [float(l) for l in line.split("\t")]
        if len(d)>2:
            if d[1] in lambdas:
                parseddata[lambdas.index(d[1])].append(d)
            else:
                lambdas.append(d[1])
                parseddata.append([])
                parseddata[lambdas.index(d[1])].append(d)'''

#parseddata = [sorted(d, key=lambda x: x[2]) for d in parseddata]
#parseddata = sorted(parseddata, key=lambda x: x[0][1])


datasets = []

for m in [7,10,12,15,18,21]:
    
    xdat = []
    ydat = []
    yerror = []

    for d in datadict:
        dd = [float(ddd) for ddd in d]
        if dd[2] == 32 and dd[1] == m and dd[0]>.075:
            t = dd[0]
            print t,"\t",dd[2],"\t",numpy.average(datadict[d][0])
            xdat.append(d[0])
            ydat.append(numpy.average(datadict[d][0])/numpy.exp(1./t))
            yerror.append(numpy.sqrt(sum([d*d/numpy.sqrt(10.) for d in datadict[d][1]]))/(10.*numpy.exp(1./t)))

    datasets.append([m,xdat,ydat,yerror])
# Out:
# 0.26 	32.0 	99.9806200441
# 0.28 	32.0 	68.8329442986
# 0.08 	32.0 	26243504291.4
# 0.23 	32.0 	151.890983408
# 0.21 	32.0 	283.606548697
# 0.31 	32.0 	44.5201765596
# 0.22 	32.0 	210.756951008
# 0.1 	32.0 	116968995.146
# 0.12 	32.0 	1494299.2293
# 0.39 	32.0 	20.94305675
# 0.11 	32.0 	10922888.61
# 0.14 	32.0 	41901.4441314
# 0.24 	32.0 	149.07445978
# 0.34 	32.0 	32.8400637225
# 0.17 	32.0 	1073.49408242
# 0.33 	32.0 	36.7953007599
# 0.4 	32.0 	18.1159561379
# 0.38 	32.0 	21.8175074659
# 0.2 	32.0 	310.183601201
# 0.25 	32.0 	110.940524235
# 0.35 	32.0 	29.7458824074
# 0.18 	32.0 	595.813494979
# 0.32 	32.0 	39.2211355123
# 0.36 	32.0 	28.5324459744
# 0.27 	32.0 	76.4776007779
# 0.19 	32.0 	442.968040826
# 0.13 	32.0 	242419.185696
# 0.37 	32.0 	24.5279973088
# 0.16 	32.0 	2603.81590802
# 0.09 	32.0 	2011466084.68
# 0.15 	32.0 	10010.6516573
# 0.29 	32.0 	56.9273981557
# 0.3 	32.0 	54.5188110834
# 0.1 	32.0 	40238793.3213
# 0.34 	32.0 	34.5505772429
# 0.25 	32.0 	119.878092635
# ...

# %%
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-small')


plt.subplot(111,  yscale="log") 
plt.xlim(.07,.2)
plt.ylim(1*10**0,10*10**5)
plt.xlabel(r'$\rm{Temperature}$')
plt.ylabel(r'$(\Gamma/\Gamma_0)^{-1}$')
#matplotlib.pyplot.yscale('log')
#matplotlib.pyplot.xscale('log')
#labellist=[96/d[1]3,4,6,8,12,16]

tcrit = []
tcrit2 = []
for i,d in enumerate(datasets):
    xdat = [float(dd) for dd in d[1]]
    ydat = [float(dd) for dd in d[2]]
    yerror = [float (dd) for dd in d[3]]
    mfrac = d[0]
    
    thisdata = []
    for j,t in enumerate(xdat):
        thisdata.append([xdat[j],ydat[j],yerror[j]])

    thisdata = sorted(thisdata, key = lambda x: x[0])

    xdat = [t[0] for t in thisdata]
    ydat = [t[1] for t in thisdata]
    yerror = [t[2] for t in thisdata]
    
    
    plt.errorbar(xdat,ydat,label=r'$m$=3/' + str(mfrac), \
                linestyle='-',markersize=5,marker='.',linewidth=0.5,elinewidth=.5,color=colors[i],\
               yerr = yerror)
    
    zipped = zip(xdat,ydat)
    
    zipped = sorted(zipped, key=lambda x: x[0])
    
    zipped = filter(lambda x: x[1] > 10, zipped)
    print zipped[-2:]
    slope = (float(zipped[-2][1]) - float(zipped[-1][1]))/.01
    b = float(zipped[-2][1]) - slope*float(zipped[-2][0])
    print mfrac,"\t",-b/slope
    
    slope2 = (float(zipped[-3][1]) - float(zipped[-2][1]))/.01
    b2 = float(zipped[-3][1]) - slope2*float(zipped[-3][0])
    
    tcrit2.append((float(mfrac),-b2/slope2))
    tcrit.append((float(mfrac),-b/slope))
#print [dd[4]/dd[3] for dd in d]
#plt.loglog([dd[2] for dd in d],[dd[3]+dd[4] for dd in d], \
#               linestyle='-',markersize=5,marker='_',linewidth=0,color='black')
#plt.loglog([dd[2] for dd in d],[dd[3]-dd[4] for dd in d], \
#                linestyle='-',markersize=5,marker='_',linewidth=0,color='black')

#print handlelist
#plt.legend(loc=2,ncol=2,numpoints=1,bbox_to_anchor=(1.05, 1), borderaxespad=0.)
leg = plt.legend(loc=1,ncol=2,numpoints=1, borderaxespad=.5,prop = fontP, frameon=False)

for legobj in leg.legendHandles:
    legobj.set_linewidth(.5)


plt.savefig('LifetimeVsMeasurementFraction'+'.pdf',dpi=600,bbox_inches='tight')


xdat = []
ydat = []
yerror = []


for t in tcrit:
    xdat.append(3./t[0])
    ydat.append(t[1])
    
print ydat
print tcrit
print tcrit2

yerror = [abs(t1[1]-t2[1]) for t1,t2 in zip(tcrit,tcrit2)]
    
f, ax = plt.subplots()

fontP = FontProperties()
fontP.set_size('x-small')


plt.subplot(111) 
plt.xlim(0.,.5)
plt.ylim(.07,.15)
plt.xlabel(r'$m=\lambda_m/(\lambda_m+\lambda_b)$')
plt.ylabel(r'$\rm{Temperature}$')


plt.errorbar(xdat,ydat,yerr=yerror,label=r'$T_c$', \
linestyle='-',markersize=5,marker='o',linewidth=0,elinewidth=.5,color=colors[0])#,\
#yerr = yerror)
leg = plt.legend(loc=1,ncol=2,numpoints=1, borderaxespad=.5,prop = fontP, frameon=False)
plt.savefig('CriticalTempVsMeasurementFraction'+'.pdf',dpi=600,bbox_inches='tight')
# Out:
# [(0.14, 33.122686110631534), (0.15, 12.739893672463625)]
# 7 	0.123749681889
# [(0.12, 64.65361737399788), (0.13, 20.660017289270655)]
# 10 	0.105303858459
# [(0.11, 134.93509412591683), (0.12, 34.431874192907095)]
# 12 	0.0965740526308
# [(0.11, 56.70584320852839), (0.12, 17.51602184344409)]
# 15 	0.0955304665259
# [(0.11, 29.514664164538036), (0.12, 10.839225460031644)]
# 18 	0.0941959995524
# [(0.1, 67.3552434624652), (0.11, 19.140072798475916)]
# 21 	0.0860302799856
# [0.1237496818892158, 0.10530385845907553, 0.09657405263076571, 0.09553046652592048, 0.09419599955238743, 0.08603027998555418]
# [(7.0, 0.1237496818892158), (10.0, 0.10530385845907553), (12.0, 0.09657405263076571), (15.0, 0.09553046652592048), (18.0, 0.09419599955238743), (21.0, 0.08603027998555418)]
# [(7.0, 0.11572604889310527), (10.0, 0.0968221550687345), (12.0, 0.08768613610457322), (15.0, 0.08671038384753721), (18.0, 0.08689734358087697), (21.0, 0.07779443858855141)]

# %%
ParamList = []
counter = 0
for Patch_Size in [7,10,15]:
    for Num_Of_Lambdas in [2,3,4,6,8,12,16,24,32]:
        for Temperature_ in sorted(numpy.linspace(.07,.4,34), reverse = True):
            ParamList.append([counter,Patch_Size, Num_Of_Lambdas, Temperature_])
            counter+=1

# %%
ParamList
# Out:
# [[0, 7, 2, 0.40000000000000002],
#  [1, 7, 2, 0.39000000000000001],
#  [2, 7, 2, 0.38],
#  [3, 7, 2, 0.37],
#  [4, 7, 2, 0.35999999999999999],
#  [5, 7, 2, 0.35000000000000003],
#  [6, 7, 2, 0.34000000000000002],
#  [7, 7, 2, 0.33000000000000002],
#  [8, 7, 2, 0.32000000000000001],
#  [9, 7, 2, 0.31],
#  [10, 7, 2, 0.30000000000000004],
#  [11, 7, 2, 0.29000000000000004],
#  [12, 7, 2, 0.28000000000000003],
#  [13, 7, 2, 0.27000000000000002],
#  [14, 7, 2, 0.26000000000000001],
#  [15, 7, 2, 0.25],
#  [16, 7, 2, 0.24000000000000002],
#  [17, 7, 2, 0.23000000000000001],
#  [18, 7, 2, 0.22],
#  [19, 7, 2, 0.21000000000000002],
#  [20, 7, 2, 0.20000000000000001],
#  [21, 7, 2, 0.19],
#  [22, 7, 2, 0.17999999999999999],
#  [23, 7, 2, 0.17000000000000001],
#  [24, 7, 2, 0.16],
#  [25, 7, 2, 0.15000000000000002],
#  [26, 7, 2, 0.14000000000000001],
#  [27, 7, 2, 0.13],
#  [28, 7, 2, 0.12000000000000001],
#  [29, 7, 2, 0.11000000000000001],
#  [30, 7, 2, 0.10000000000000001],
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.



X = []
Y = []
Z = []
for d in datadict:
    if int(d[2])==24:
        Z.append(numpy.log(numpy.average(datadict[d])/numpy.exp(1/float(d[0]))))
        X.append(float(d[0]))
        Y.append(float(d[2]))
    
X = numpy.array(X)
Y = numpy.array(Y)
Z = numpy.array(Z)




#X, Y = np.meshgrid(X, Y)
#R = np.sqrt(X**2 + Y**2)


# Plot the surface.
#surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
#                      linewidth=0, antialiased=False)
ax.scatter(X,Y,Z)
# Customize the z axis.
#ax.set_zlim(.01, 10.)
#ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
# Out:
# {o]E~�]~�!�g�����o�V$�Cݥ�J���_�^���:

# %%
ParamList = []
for Patch_Size in [7]:
    for Num_Of_Lambdas in [32]:
        for Temperature_ in sorted(numpy.linspace(.1,.25,16), reverse = True):
            for Delta_ in [.8,.9,1.0,1.1,1.2]:
                ParamList.append([Patch_Size, Num_Of_Lambdas, Temperature_,Delta_])

print[ParamList[78]]
print ParamList
# Out:
# [[7, 32, 0.10000000000000001, 1.1]]
# ...

# %%
datadict2 = {}
for i,m in enumerate(mydata):
    
    splitlist = m.split("\t")
    if len(splitlist)>2:
        #key = splitlist[0:4]
        #print m
        #print int(m.split("\t")[2])
        parms = ParamList[int(myfilenums[i])%80] 
        key = (parms[2],parms[3],parms[0],parms[1])
        val = splitlist[5]
        valerr = splitlist[6]
        #print key,val
        if tuple(key) in datadict2:
            #print "Found something!"
            datadict2[tuple(key)][0].append(float(val))
            datadict2[tuple(key)][1].append(float(valerr))
        else:
            datadict2[tuple(key)] = [[],[]]

# %%
datadict2
# Out:
# {(0.10000000000000001,
#   0.8,
#   7,
#   32): [[707243.607693,
#    571849.676703,
#    1033544.35712,
#    492576.680337,
#    471875.049133], [588509.853979,
#    504682.032659,
#    921292.485745,
#    395177.358434,
#    487290.037131]],
#  (0.11,
#   0.8,
#   7,
#   32): [[81272.6431694,
#    119590.382061,
#    88377.9481215,
#    94145.038495,
#    141538.760939,
#    68247.2291229,
#    97171.5568262,
#    74401.0943551,
#    133051.018896], [63577.0508503,
#    129267.752723,
#    62975.205674,
#    110175.85797,
#    93172.0788379,
#    59502.5482808,
#    84304.5532443,
#    56582.6685525,
#    93440.9030068]],
#  (0.11, 0.9, 7, 32): [[1005988.96473], [882824.687747]],
#  (0.12000000000000001,
#   0.8,
#   7,
#   32): [[9831.19295484,
#    16651.4039405,
#    11909.8936513,
#    16235.171791,
#    13834.8992369,
#    9312.32180987,
#    10665.7136071,
#    19838.5839328,
#    20522.5052472], [6690.03733487,
#    8494.50563584,
#    7776.72052622,
#    13136.455931,
# ...

# %%
saveFig = False

f, ax = plt.subplots()

parseddata = []
'''lambdas = []
with open("outputwitherror_fixed.txt") as f:
    data = f.readlines()
    for line in data:
        d = [float(l) for l in line.split("\t")]
        if len(d)>2:
            if d[1] in lambdas:
                parseddata[lambdas.index(d[1])].append(d)
            else:
                lambdas.append(d[1])
                parseddata.append([])
                parseddata[lambdas.index(d[1])].append(d)'''

#parseddata = [sorted(d, key=lambda x: x[2]) for d in parseddata]
#parseddata = sorted(parseddata, key=lambda x: x[0][1])


datasets = []

for x in [.8,.9,1.0,1.1,1.2]:
    
    xdat = []
    ydat = []
    yerror = []

    for d in datadict2:
        dd = [float(ddd) for ddd in d]
        if dd[1]==x:# and dd[1] == 32:
            t = dd[0]
            print t,"\t",x,"\t",dd[2],"\t",numpy.average(datadict2[d][0])
            xdat.append(d[0])
            ydat.append(dd[1]*numpy.average(datadict2[d][0])/numpy.exp(dd[1]*1./t))
            yerror.append(numpy.sqrt(sum([d*d/numpy.sqrt(10.) for d in datadict2[d][1]]))/(10.*dd[1]*numpy.exp(dd[1]*1./t)))

    datasets.append([x,xdat,ydat,yerror])
# Out:
# 0.12 	0.8 	7.0 	14311.2984635
# 0.13 	0.8 	7.0 	4057.76350346
# 0.15 	0.8 	7.0 	610.050639929
# 0.25 	0.8 	7.0 	58.4381424938
# 0.11 	0.8 	7.0 	99755.0746651
# 0.2 	0.8 	7.0 	145.036722907
# 0.17 	0.8 	7.0 	367.471115586
# 0.1 	0.8 	7.0 	655417.874197
# 0.22 	0.8 	7.0 	103.161368831
# 0.18 	0.8 	7.0 	272.566115395
# 0.16 	0.8 	7.0 	470.847424577
# 0.14 	0.8 	7.0 	1149.56300933
# 0.24 	0.8 	7.0 	73.0824041932
# 0.23 	0.8 	7.0 	87.6945292893
# 0.19 	0.8 	7.0 	207.90866702
# 0.21 	0.8 	7.0 	128.898848455
# 0.24 	0.9 	7.0 	102.410428406
# 0.2 	0.9 	7.0 	198.585359843
# 0.16 	0.9 	7.0 	849.940017731
# 0.17 	0.9 	7.0 	528.628446886
# 0.13 	0.9 	7.0 	24901.3722001
# 0.22 	0.9 	7.0 	140.633440012
# 0.25 	0.9 	7.0 	78.2622803612
# 0.15 	0.9 	7.0 	1801.03669642
# 0.21 	0.9 	7.0 	177.908917513
# 0.18 	0.9 	7.0 	390.244722334
# 0.14 	0.9 	7.0 	5183.9070097
# 0.23 	0.9 	7.0 	117.550710594
# 0.19 	0.9 	7.0 	298.662044458
# 0.11 	0.9 	7.0 	1005988.96473
# 0.12 	0.9 	7.0 	171456.449037
# ...

# %%
from matplotlib.font_manager import FontProperties

fontP = FontProperties()
fontP.set_size('x-small')


plt.subplot(111,  yscale="log") 
plt.xlim(0.095,.26)
plt.ylim(1*10**0,1*10**3)
plt.xlabel(r'$\rm{Temperature}$')
plt.ylabel(r'$(\Gamma/\Gamma_0)^{-1}$')
#matplotlib.pyplot.yscale('log')
#matplotlib.pyplot.xscale('log')
#labellist=[96/d[1]3,4,6,8,12,16]


tcrit = []
tcrit2 = []




for i,d in enumerate(datasets):
    xdat = d[1]
    ydat = d[2]
    yerror = d[3]
    size = d[0]
    
    mfrac = size
    
    thisdata = []
    for j,t in enumerate(xdat):
        thisdata.append([xdat[j],ydat[j],yerror[j]])

    thisdata = sorted(thisdata, key = lambda x: x[0])

    xdat = [t[0] for t in thisdata]
    ydat = [t[1] for t in thisdata]
    yerror = [t[2] for t in thisdata]
    
    
    print ydat
    
    plt.errorbar(xdat,ydat,label=r'$\Delta$=' + str(size), \
                linestyle='dotted',markersize=5,marker='.',linewidth=0.5,elinewidth=.5,color=colors[i],\
               yerr = yerror)
    
    
    zipped = zip(xdat,ydat)
    
    zipped = sorted(zipped, key=lambda x: x[0])
    
    zipped = filter(lambda x: x[1] > 10, zipped)
    print zipped[-2:]
    slope = (float(zipped[-2][1]) - float(zipped[-1][1]))/.01
    b = float(zipped[-2][1]) - slope*float(zipped[-2][0])
    print mfrac,"\t",-b/slope
    
    slope2 = (float(zipped[-3][1]) - float(zipped[-2][1]))/.01
    b2 = float(zipped[-3][1]) - slope2*float(zipped[-3][0])
    
    tcrit2.append((float(mfrac),-b2/slope2))
    tcrit.append((float(mfrac),-b/slope))
#print [dd[4]/dd[3] for dd in d]
#plt.loglog([dd[2] for dd in d],[dd[3]+dd[4] for dd in d], \
#               linestyle='-',markersize=5,marker='_',linewidth=0,color='black')
#plt.loglog([dd[2] for dd in d],[dd[3]-dd[4] for dd in d], \
#                linestyle='-',markersize=5,marker='_',linewidth=0,color='black')

#print handlelist
#plt.legend(loc=2,ncol=2,numpoints=1,bbox_to_anchor=(1.05, 1), borderaxespad=0.)
leg = plt.legend(loc=1,ncol=2,numpoints=1, borderaxespad=.5,prop = fontP, frameon=False)

for legobj in leg.legendHandles:
    legobj.set_linewidth(.5)


plt.savefig('LifetimeVsTemperatureVsEnergy'+'.pdf',dpi=600,bbox_inches='tight')




xdat = []
ydat = []
yerror = []


for t in tcrit:
    xdat.append(t[0])
    ydat.append(t[1])
    
print ydat
print tcrit
print tcrit2

yerror = [abs(t1[1]-t2[1]) for t1,t2 in zip(tcrit,tcrit2)]
    
f, ax = plt.subplots()

fontP = FontProperties()
fontP.set_size('x-small')


plt.subplot(111) 
plt.xlim(0.75,1.25)
plt.ylim(.07,.16)
plt.xlabel(r'$\Delta$')
plt.ylabel(r'$\rm{Temperature}$')


plt.errorbar(xdat,ydat,yerr=yerror,label=r'$T_c$', \
linestyle='-',markersize=5,marker='o',linewidth=0,elinewidth=.5,color=colors[0])#,\
#yerr = yerror)
#leg = plt.legend(loc=1,ncol=2,numpoints=1, borderaxespad=.5,prop = fontP, frameon=False)
plt.savefig('CriticalTempVsDelta'+'.pdf',dpi=600,bbox_inches='tight')
# Out:
# [175.89456196197651, 55.401262552640482, 14.570433732571191, 6.8991453005004217, 3.0334721624740806, 2.3562351866256663, 2.5380359931669703, 2.6581192245347216, 2.5607321513359049, 2.4680516045809053, 2.1251521938911262, 2.2849876406827034, 2.1744750133950763, 2.1650752031713449, 2.0857129607928111, 1.9056539875581977]
# [(0.11, 55.401262552640482), (0.12000000000000001, 14.570433732571191)]
# 0.8 	0.0964315116412
# [253.23121449111318, 85.346893911293179, 22.070475180373201, 7.5336703678016539, 4.0178912683464443, 2.7588261021965845, 2.3888394292040114, 2.3665034301813637, 2.356341082383667, 1.9854756675406735, 2.2038303587038621, 2.1167611953308403, 2.1137546605223707, 2.1676161854348841, 1.9245751440140084]
# [(0.12000000000000001, 85.346893911293179), (0.13, 22.070475180373201)]
# 0.9 	0.106512053681
# ...

# %%
print xdat
# Out:
# [0.8, 0.9, 1.0, 1.1, 1.2]

# %%
print ydat
# Out:
# [0.0964315116411721, 0.10651205368081484, 0.12338121244167206, 0.13208331789998237, 0.1429902204403659]
